# %%
# !wget https://bin.equinox.io/c/4VmDzA7iaHb/ngrok-stable-linux-amd64.zip
# !unzip ngrok-stable-linux-amd64.zip
# # Install
! npm install -g localtunnel
# Out:
# /tools/node/bin/lt -> /tools/node/lib/node_modules/localtunnel/bin/client
# + localtunnel@1.9.1
# added 54 packages from 30 contributors in 2.612s

# %%
# !umount -l drive

# %%
# !ls /content/drive/My\ Drive/lower_level_api/trained_models/
# Out:
# estimator-demo-0925030157

# %%
from google.colab import drive
drive.mount("/content/drive")
# Out:
# Mounted at /content/drive

# %%
# !rm url.txt
get_ipython().system_raw(
    'tensorboard --logdir {} --host 0.0.0.0 --port 6006 &'
    .format("/content/drive/My\ Drive/lower_level_api/trained_models")
)

# Tunnel port 6006 (TensorBoard assumed running)
get_ipython().system_raw('lt --port 6006 >> url.txt 2>&1 &')

# %%
#!rm url.txt
# !cat url.txt
# Out:
# your url is: https://shaggy-newt-87.localtunnel.me

# %%
# !ps -ef | grep 6006
# Out:
# root      5294     1  3 04:14 ?        00:00:01 /usr/bin/python2 /usr/local/bin/tensorboard --logdir=/content/drive/My Drive/lower_level_api/trained_models --host 0.0.0.0 --port 6006
# root      5296     1  0 04:14 ?        00:00:00 node /tools/node/bin/lt --port 6006
# root      5347  5204  0 04:15 ?        00:00:00 /bin/bash -c ps -ef | grep 6006
# root      5349  5347  0 04:15 ?        00:00:00 grep 6006

# %%
# !kill -9 5296

# %% [markdown]
# # Use tensorboard on Colab
#
# ## Trouble shooting
#
# ### Error: connection refused (check your firewall settings)
#
# /tools/node/lib/node_modules/localtunnel/bin/client:65
#         throw err;
#         ^
#
# Error: connection refused: localtunnel.me:46732 (check your firewall settings)
#     at Socket.<anonymous> (/tools/node/lib/node_modules/localtunnel/lib/TunnelCluster.js:47:32)
#     at emitOne (events.js:116:13)
#     at Socket.emit (events.js:211:7)
#     at emitErrorNT (internal/streams/destroy.js:64:8)
#     at _combinedTickCallback (internal/process/next_tick.js:138:11)
#     at process._tickCallback (internal/process/next_tick.js:180:9)
# /bin/bash: lt: command not found
#
# ### Solution:
# ```
# ! npm install -g localtunnel
# ```
#
#
# Before restarting another tensorboard command, make sure you have killed the session before using:
# ```
# !ps -ef | grep 6006
# !kill -s PID
#
# ```
